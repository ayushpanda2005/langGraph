# %%
# start ->gen_outline->gen_blog->end
#basically the practise of using >1 llms in a row

# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str 
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title=state['title']
    prompt=f'Generate a detailed outline for a blog on the topic - {title} under 30 words'
    outline = model.invoke(prompt).content
    state['outline']=outline 
    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title =  state['title']
    outline = state['outline'] 

    prompt = f'Write a detailed blog on the title - {title} using the following outline\n {outline} under 60 words'
    content = model.invoke(prompt).content

    state['content'] = content

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

app=graph.compile()

# %%
init_state = {'title':'Rise of ai in india'}
final_state = app.invoke(init_state)
print(final_state)
# Out:
# {'title': 'Rise of ai in india', 'outline': "I. Introduction \n    A. Definition of AI \n    B. Overview of AI technology in India \nII. Current AI landscape in India \n    A. Major players in the AI industry \n    B. Impact of AI on various sectors \nIII. Government initiatives in promoting AI \n    A. AI policies and regulations \n    B. Funding for AI research and development \nIV. Challenges and opportunities in the AI industry \n    A. Skills gap and talent shortage \n    B. Potential for economic growth through AI adoption \nV. Future of AI in India \n    A. Emerging trends in AI technology \n    B. Predictions for the future growth of AI in India \nVI. Conclusion \n    A. Summary of key points \n    B. The potential impact of AI on India's economy and society"}

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Definition of AI
#     B. Overview of AI technology in India
# II. Current AI landscape in India
#     A. Major players in the AI industry
#     B. Impact of AI on various sectors
# III. Government initiatives in promoting AI
#     A. AI policies and regulations
#     B. Funding for AI research and development
# IV. Challenges and opportunities in the AI industry
#     A. Skills gap and talent shortage
#     B. Potential for economic growth through AI adoption
# V. Future of AI in India
#     A. Emerging trends in AI technology
#     B. Predictions for the future growth of AI in India
# VI. Conclusion
#     A. Summary of key points
#     B. The potential impact of AI on India's economy and society
